# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip uninstall -y tensorflow
# !pip install tensorflow-cpu

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.models import resnet18
from sklearn.metrics import accuracy_score, roc_auc_score
from concurrent.futures import ThreadPoolExecutor, as_completed
import torch_xla
import torch_xla.core.xla_model as xm
from torch_xla.distributed.parallel_loader import MpDeviceLoader
from torchvision.models import resnet50

# %%
# Define main directories
main_dir = "/content/drive/My Drive/DATASET_MRNET/MRNet-v1.0"
train_path = os.path.join(main_dir, "train")
valid_path = os.path.join(main_dir, "valid")

# %%
def load_labels(label_type):
    train_labels = pd.read_csv(os.path.join(main_dir, f"train-{label_type}.csv"),
                               header=None, index_col=0).squeeze("columns").to_dict()
    valid_labels = pd.read_csv(os.path.join(main_dir, f"valid-{label_type}.csv"),
                               header=None, index_col=0).squeeze("columns").to_dict()
    return train_labels, valid_labels

# %%
train_abnormal, valid_abnormal = load_labels("abnormal")
train_acl, valid_acl = load_labels("acl")
train_meniscus, valid_meniscus = load_labels("meniscus")

# %%
def pad_to_shape(scan, target_shape):
    padded_scan = np.zeros(target_shape, dtype=scan.dtype)
    min_d = min(scan.shape[0], target_shape[0])
    min_h = min(scan.shape[1], target_shape[1])
    min_w = min(scan.shape[2], target_shape[2])
    padded_scan[:min_d, :min_h, :min_w] = scan[:min_d, :min_h, :min_w]
    return padded_scan

# %%
def pad_or_crop_scan(scan, target_shape=(48, 256, 256)):
    d, h, w = scan.shape
    td, th, tw = target_shape

    # Pad or crop depth
    if d < td:
        pad_width = ((0, td - d), (0, 0), (0, 0))
        scan = np.pad(scan, pad_width=pad_width, mode='constant', constant_values=0)
    elif d > td:
        start = (d - td) // 2
        scan = scan[start:start+td, :, :]

    # Pad or crop height and width
    scan = pad_to_shape(scan, target_shape)
    return scan

# %% [markdown]
# Starting with Axial axes

# %%
def load_single_axis_mri_data(data_type="train", start_idx=0, end_idx=9, target_shape=(48, 256, 256)):
    data_path = train_path if data_type == "train" else valid_path
    abnormal_labels = train_abnormal if data_type == "train" else valid_abnormal
    acl_labels = train_acl if data_type == "train" else valid_acl
    meniscus_labels = train_meniscus if data_type == "train" else valid_meniscus

    data = []
    labels = []

    for i in range(start_idx, end_idx + 1):
        file_name = f"{i:04}.npy"
        scan = np.load(Path(data_path) / "axial" / file_name)
        scan = pad_or_crop_scan(scan, target_shape)

        # Convert 3D (D,H,W) to 2D by taking the middle slice
        d = scan.shape[0]
        mid_slice = d // 2
        single_slice = scan[mid_slice, :, :]  # shape (H, W)

        # Add channel dimension: (1, H, W)
        single_slice = np.expand_dims(single_slice, axis=0)
        data.append(single_slice)  # will become (1,H,W)

        # Labels: [abnormal, acl, meniscus]
        abnormal_label = abnormal_labels.get(i, 0)
        acl_label = acl_labels.get(i, 0)
        meniscus_label = meniscus_labels.get(i, 0)
        labels.append([abnormal_label, acl_label, meniscus_label])

    data = np.array(data)    # (N, 1, H, W)
    labels = np.array(labels) # (N, 3)
    return data, labels

# %%
def load_data_in_batches(start_indices, end_indices, data_type):
    all_data = []
    all_labels = []

    with ThreadPoolExecutor() as executor:
        future_to_indices = {
            executor.submit(load_single_axis_mri_data, data_type, start, end): (start, end)
            for start, end in zip(start_indices, end_indices)
        }
        for future in as_completed(future_to_indices):
            data, labels = future.result()
            all_data.append(data)
            all_labels.append(labels)

    all_data = np.concatenate(all_data, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)
    return all_data, all_labels

# %%
start_indices = list(range(0, 1130, 100))
end_indices = [min(start + 99, 1129) for start in start_indices]

train_data, train_labels = load_data_in_batches(start_indices, end_indices, "train")
valid_data, valid_labels = load_single_axis_mri_data("valid", 1130, 1249)

print("Train data shape:", train_data.shape)   # (N,1,H,W)
print("Train labels shape:", train_labels.shape)# (N,3)
print("Valid data shape:", valid_data.shape)
print("Valid labels shape:", valid_labels.shape)
# Out:
# Train data shape: (1130, 1, 256, 256)
# Train labels shape: (1130, 3)
# Valid data shape: (120, 1, 256, 256)
# Valid labels shape: (120, 3)

# %%
class SingleChannelResNet18(nn.Module):
    def __init__(self, num_classes=3):
        super(SingleChannelResNet18, self).__init__()
        self.model = resnet18()
        # Modify the first conv layer to accept 1-channel input
        # Original: Conv2d(3,64,kernel_size=7,stride=2,padding=3,bias=False)
        original_conv1 = self.model.conv1
        self.model.conv1 = nn.Conv2d(
            in_channels=1,
            out_channels=original_conv1.out_channels,
            kernel_size=original_conv1.kernel_size,
            stride=original_conv1.stride,
            padding=original_conv1.padding,
            bias=original_conv1.bias
        )
        # Change the final FC layer
        in_features = self.model.fc.in_features
        self.model.fc = nn.Linear(in_features, num_classes)

    def forward(self, x):
        return self.model(x)

# %%
class MRNetDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        x = torch.tensor(self.data[idx], dtype=torch.float32)   # (1,H,W)
        y = torch.tensor(self.labels[idx], dtype=torch.float32) # (3,)
        return x, y

# %%
# Use TPU device
device = xm.xla_device()

# %%
train_dataset = MRNetDataset(train_data, train_labels)
valid_dataset = MRNetDataset(valid_data, valid_labels)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=8, shuffle=False)

train_loader = MpDeviceLoader(train_loader, device)
valid_loader = MpDeviceLoader(valid_loader, device)

# %%
model = SingleChannelResNet18(num_classes=3).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def train_and_validate(model, train_loader, valid_loader, criterion, optimizer, epochs=10, classes=["abnormal", "acl", "meniscus"]):
    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_loss = 0
        train_preds = {cls: [] for cls in classes}
        train_truth = {cls: [] for cls in classes}

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            outputs = model(x)  # (N,3)
            loss = criterion(outputs, y)
            loss.backward()
            xm.optimizer_step(optimizer)

            train_loss += loss.item()
            preds_sig = torch.sigmoid(outputs).detach().cpu().numpy()  # (N,3)
            labels_np = y.detach().cpu().numpy()                       # (N,3)

            for i, cls in enumerate(classes):
                train_preds[cls].extend(preds_sig[:, i])
                train_truth[cls].extend(labels_np[:, i])

        train_loss /= len(train_loader)

        # Validation Phase
        model.eval()
        valid_loss = 0
        valid_preds = {cls: [] for cls in classes}
        valid_truth = {cls: [] for cls in classes}

        with torch.no_grad():
            for x, y in valid_loader:
                x, y = x.to(device), y.to(device)
                outputs = model(x)
                loss = criterion(outputs, y)
                valid_loss += loss.item()

                preds_sig = torch.sigmoid(outputs).cpu().numpy()
                labels_np = y.cpu().numpy()
                for i, cls in enumerate(classes):
                    valid_preds[cls].extend(preds_sig[:, i])
                    valid_truth[cls].extend(labels_np[:, i])

        valid_loss /= len(valid_loader)

        print(f"Epoch {epoch+1}/{epochs}")
        print(f"Train Loss: {train_loss:.4f} | Valid Loss: {valid_loss:.4f}")

        # Compute total accuracy
        # Convert dictionary lists into arrays of shape (N,3)
        train_pred_matrix = np.column_stack([train_preds[cls] for cls in classes])
        train_truth_matrix = np.column_stack([train_truth[cls] for cls in classes])
        valid_pred_matrix = np.column_stack([valid_preds[cls] for cls in classes])
        valid_truth_matrix = np.column_stack([valid_truth[cls] for cls in classes])

        # Threshold predictions at 0.5
        train_binary_preds = (train_pred_matrix > 0.5).astype(int)
        valid_binary_preds = (valid_pred_matrix > 0.5).astype(int)

        # Print per-class metrics
        for cls in classes:
            train_acc = accuracy_score(train_truth[cls], (np.array(train_preds[cls]) > 0.5).astype(int))
            valid_acc = accuracy_score(valid_truth[cls], (np.array(valid_preds[cls]) > 0.5).astype(int))

            # ROC-AUC might require both classes present in data
            if len(np.unique(train_truth[cls])) > 1:
                train_roc = roc_auc_score(train_truth[cls], train_preds[cls])
            else:
                train_roc = float('nan')
            if len(np.unique(valid_truth[cls])) > 1:
                valid_roc = roc_auc_score(valid_truth[cls], valid_preds[cls])
            else:
                valid_roc = float('nan')

            print(f"\nClass: {cls.upper()}")
            print(f"Train Acc: {train_acc:.4f}, Train ROC-AUC: {train_roc:.4f}")
            print(f"Valid Acc: {valid_acc:.4f}, Valid ROC-AUC: {valid_roc:.4f}")

        print("---------------------------------------------------")

# %%
classes = ["abnormal", "acl", "meniscus"]

# %%
train_and_validate(model, train_loader, valid_loader, criterion, optimizer, epochs=20, classes=classes)
# Out:
# Epoch 1/20
# Train Loss: 0.4838 | Valid Loss: 0.9988
#
# Class: ABNORMAL
# Train Acc: 0.8071, Train ROC-AUC: 0.7934
# Valid Acc: 0.7500, Valid ROC-AUC: 0.6926
#
# Class: ACL
# Train Acc: 0.8124, Train ROC-AUC: 0.6276
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5881
#
# Class: MENISCUS
# Train Acc: 0.6805, Train ROC-AUC: 0.6955
# Valid Acc: 0.5333, Valid ROC-AUC: 0.6674
# ---------------------------------------------------
# Epoch 2/20
# Train Loss: 0.4919 | Valid Loss: 0.6691
#
# Class: ABNORMAL
# Train Acc: 0.7903, Train ROC-AUC: 0.7899
# Valid Acc: 0.7250, Valid ROC-AUC: 0.7242
#
# Class: ACL
# Train Acc: 0.8168, Train ROC-AUC: 0.6451
# Valid Acc: 0.5583, Valid ROC-AUC: 0.5629
#
# Class: MENISCUS
# Train Acc: 0.6637, Train ROC-AUC: 0.6677
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6643
# ---------------------------------------------------
# Epoch 3/20
# Train Loss: 0.4839 | Valid Loss: 2.7417
#
# Class: ABNORMAL
# Train Acc: 0.8044, Train ROC-AUC: 0.7869
# Valid Acc: 0.7917, Valid ROC-AUC: 0.6139
#
# Class: ACL
# Train Acc: 0.8230, Train ROC-AUC: 0.6757
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5951
#
# Class: MENISCUS
# Train Acc: 0.6770, Train ROC-AUC: 0.6825
# Valid Acc: 0.4583, Valid ROC-AUC: 0.6700
# ---------------------------------------------------
# Epoch 4/20
# Train Loss: 0.4791 | Valid Loss: 1.4976
#
# Class: ABNORMAL
# Train Acc: 0.8133, Train ROC-AUC: 0.8054
# Valid Acc: 0.7917, Valid ROC-AUC: 0.6493
#
# Class: ACL
# Train Acc: 0.8159, Train ROC-AUC: 0.6785
# Valid Acc: 0.5500, Valid ROC-AUC: 0.6111
#
# Class: MENISCUS
# Train Acc: 0.6805, Train ROC-AUC: 0.6888
# Valid Acc: 0.4917, Valid ROC-AUC: 0.6513
# ---------------------------------------------------
# Epoch 5/20
# Train Loss: 0.4753 | Valid Loss: 0.6515
#
# Class: ABNORMAL
# Train Acc: 0.7991, Train ROC-AUC: 0.8105
# Valid Acc: 0.7833, Valid ROC-AUC: 0.7364
#
# Class: ACL
# Train Acc: 0.8221, Train ROC-AUC: 0.6860
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5920
#
# Class: MENISCUS
# Train Acc: 0.6973, Train ROC-AUC: 0.6988
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6417
# ---------------------------------------------------
# Epoch 6/20
# Train Loss: 0.4651 | Valid Loss: 0.7025
#
# Class: ABNORMAL
# Train Acc: 0.8150, Train ROC-AUC: 0.8215
# Valid Acc: 0.7750, Valid ROC-AUC: 0.6922
#
# Class: ACL
# Train Acc: 0.8159, Train ROC-AUC: 0.7022
# Valid Acc: 0.5583, Valid ROC-AUC: 0.5542
#
# Class: MENISCUS
# Train Acc: 0.6912, Train ROC-AUC: 0.7175
# Valid Acc: 0.5583, Valid ROC-AUC: 0.5998
# ---------------------------------------------------
# Epoch 7/20
# Train Loss: 0.4629 | Valid Loss: 0.9365
#
# Class: ABNORMAL
# Train Acc: 0.8257, Train ROC-AUC: 0.8315
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7032
#
# Class: ACL
# Train Acc: 0.8292, Train ROC-AUC: 0.7063
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5631
#
# Class: MENISCUS
# Train Acc: 0.7142, Train ROC-AUC: 0.7165
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6578
# ---------------------------------------------------
# Epoch 8/20
# Train Loss: 0.4482 | Valid Loss: 0.8793
#
# Class: ABNORMAL
# Train Acc: 0.8115, Train ROC-AUC: 0.8334
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7267
#
# Class: ACL
# Train Acc: 0.8301, Train ROC-AUC: 0.7346
# Valid Acc: 0.5583, Valid ROC-AUC: 0.5671
#
# Class: MENISCUS
# Train Acc: 0.7177, Train ROC-AUC: 0.7428
# Valid Acc: 0.6083, Valid ROC-AUC: 0.6420
# ---------------------------------------------------
# Epoch 9/20
# Train Loss: 0.4429 | Valid Loss: 0.7113
#
# Class: ABNORMAL
# Train Acc: 0.8327, Train ROC-AUC: 0.8586
# Valid Acc: 0.7833, Valid ROC-AUC: 0.7175
#
# Class: ACL
# Train Acc: 0.8336, Train ROC-AUC: 0.7487
# Valid Acc: 0.5417, Valid ROC-AUC: 0.5384
#
# Class: MENISCUS
# Train Acc: 0.7186, Train ROC-AUC: 0.7335
# Valid Acc: 0.5833, Valid ROC-AUC: 0.6315
# ---------------------------------------------------
# Epoch 10/20
# Train Loss: 0.4491 | Valid Loss: 0.7318
#
# Class: ABNORMAL
# Train Acc: 0.8248, Train ROC-AUC: 0.8467
# Valid Acc: 0.7750, Valid ROC-AUC: 0.6985
#
# Class: ACL
# Train Acc: 0.8310, Train ROC-AUC: 0.7421
# Valid Acc: 0.5250, Valid ROC-AUC: 0.4896
#
# Class: MENISCUS
# Train Acc: 0.7124, Train ROC-AUC: 0.7346
# Valid Acc: 0.6000, Valid ROC-AUC: 0.6264
# ---------------------------------------------------
# Epoch 11/20
# Train Loss: 0.4240 | Valid Loss: 0.9745
#
# Class: ABNORMAL
# Train Acc: 0.8398, Train ROC-AUC: 0.8697
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7309
#
# Class: ACL
# Train Acc: 0.8354, Train ROC-AUC: 0.7546
# Valid Acc: 0.5583, Valid ROC-AUC: 0.5755
#
# Class: MENISCUS
# Train Acc: 0.7292, Train ROC-AUC: 0.7761
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6174
# ---------------------------------------------------
# Epoch 12/20
# Train Loss: 0.4059 | Valid Loss: 0.8134
#
# Class: ABNORMAL
# Train Acc: 0.8416, Train ROC-AUC: 0.8760
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7322
#
# Class: ACL
# Train Acc: 0.8257, Train ROC-AUC: 0.7828
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6229
#
# Class: MENISCUS
# Train Acc: 0.7646, Train ROC-AUC: 0.7971
# Valid Acc: 0.6000, Valid ROC-AUC: 0.6417
# ---------------------------------------------------
# Epoch 13/20
# Train Loss: 0.3855 | Valid Loss: 0.9770
#
# Class: ABNORMAL
# Train Acc: 0.8664, Train ROC-AUC: 0.9006
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7002
#
# Class: ACL
# Train Acc: 0.8531, Train ROC-AUC: 0.8040
# Valid Acc: 0.6000, Valid ROC-AUC: 0.5845
#
# Class: MENISCUS
# Train Acc: 0.7717, Train ROC-AUC: 0.8171
# Valid Acc: 0.6167, Valid ROC-AUC: 0.6731
# ---------------------------------------------------
# Epoch 14/20
# Train Loss: 0.3555 | Valid Loss: 0.7879
#
# Class: ABNORMAL
# Train Acc: 0.8646, Train ROC-AUC: 0.9125
# Valid Acc: 0.7083, Valid ROC-AUC: 0.7827
#
# Class: ACL
# Train Acc: 0.8690, Train ROC-AUC: 0.8555
# Valid Acc: 0.5917, Valid ROC-AUC: 0.6597
#
# Class: MENISCUS
# Train Acc: 0.7770, Train ROC-AUC: 0.8406
# Valid Acc: 0.5917, Valid ROC-AUC: 0.6377
# ---------------------------------------------------
# Epoch 15/20
# Train Loss: 0.3240 | Valid Loss: 1.2790
#
# Class: ABNORMAL
# Train Acc: 0.8770, Train ROC-AUC: 0.9316
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7632
#
# Class: ACL
# Train Acc: 0.8876, Train ROC-AUC: 0.8925
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6120
#
# Class: MENISCUS
# Train Acc: 0.8159, Train ROC-AUC: 0.8668
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6140
# ---------------------------------------------------
# Epoch 16/20
# Train Loss: 0.2896 | Valid Loss: 0.8392
#
# Class: ABNORMAL
# Train Acc: 0.8743, Train ROC-AUC: 0.9328
# Valid Acc: 0.8167, Valid ROC-AUC: 0.7575
#
# Class: ACL
# Train Acc: 0.8947, Train ROC-AUC: 0.9126
# Valid Acc: 0.5167, Valid ROC-AUC: 0.5250
#
# Class: MENISCUS
# Train Acc: 0.8425, Train ROC-AUC: 0.9045
# Valid Acc: 0.6000, Valid ROC-AUC: 0.6055
# ---------------------------------------------------
# Epoch 17/20
# Train Loss: 0.2553 | Valid Loss: 0.9851
#
# Class: ABNORMAL
# Train Acc: 0.8982, Train ROC-AUC: 0.9524
# Valid Acc: 0.8417, Valid ROC-AUC: 0.8316
#
# Class: ACL
# Train Acc: 0.9204, Train ROC-AUC: 0.9329
# Valid Acc: 0.5333, Valid ROC-AUC: 0.6142
#
# Class: MENISCUS
# Train Acc: 0.8593, Train ROC-AUC: 0.9246
# Valid Acc: 0.5750, Valid ROC-AUC: 0.5913
# ---------------------------------------------------
# Epoch 18/20
# Train Loss: 0.2316 | Valid Loss: 1.4154
#
# Class: ABNORMAL
# Train Acc: 0.9018, Train ROC-AUC: 0.9533
# Valid Acc: 0.8000, Valid ROC-AUC: 0.7486
#
# Class: ACL
# Train Acc: 0.9354, Train ROC-AUC: 0.9572
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5675
#
# Class: MENISCUS
# Train Acc: 0.8655, Train ROC-AUC: 0.9348
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6377
# ---------------------------------------------------
# Epoch 19/20
# Train Loss: 0.1929 | Valid Loss: 1.4757
#
# Class: ABNORMAL
# Train Acc: 0.9053, Train ROC-AUC: 0.9629
# Valid Acc: 0.8167, Valid ROC-AUC: 0.7912
#
# Class: ACL
# Train Acc: 0.9496, Train ROC-AUC: 0.9680
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5738
#
# Class: MENISCUS
# Train Acc: 0.8965, Train ROC-AUC: 0.9552
# Valid Acc: 0.5833, Valid ROC-AUC: 0.5817
# ---------------------------------------------------
# Epoch 20/20
# Train Loss: 0.1882 | Valid Loss: 1.8368
#
# Class: ABNORMAL
# Train Acc: 0.9133, Train ROC-AUC: 0.9616
# Valid Acc: 0.8000, Valid ROC-AUC: 0.7596
#
# Class: ACL
# Train Acc: 0.9531, Train ROC-AUC: 0.9751
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5835
#
# Class: MENISCUS
# Train Acc: 0.9009, Train ROC-AUC: 0.9599
# Valid Acc: 0.5417, Valid ROC-AUC: 0.6202
# ---------------------------------------------------

# %% [markdown]
# Now, Coronal Axes

# %%
def load_single_axis_mri_data(data_type="train", start_idx=0, end_idx=9, target_shape=(48, 256, 256)):
    data_path = train_path if data_type == "train" else valid_path
    abnormal_labels = train_abnormal if data_type == "train" else valid_abnormal
    acl_labels = train_acl if data_type == "train" else valid_acl
    meniscus_labels = train_meniscus if data_type == "train" else valid_meniscus

    data = []
    labels = []

    for i in range(start_idx, end_idx + 1):
        file_name = f"{i:04}.npy"
        scan = np.load(Path(data_path) / "coronal" / file_name)
        scan = pad_or_crop_scan(scan, target_shape)

        # Convert 3D (D,H,W) to 2D by taking the middle slice
        d = scan.shape[0]
        mid_slice = d // 2
        single_slice = scan[mid_slice, :, :]  # shape (H, W)

        # Add channel dimension: (1, H, W)
        single_slice = np.expand_dims(single_slice, axis=0)
        data.append(single_slice)  # will become (1,H,W)

        # Labels: [abnormal, acl, meniscus]
        abnormal_label = abnormal_labels.get(i, 0)
        acl_label = acl_labels.get(i, 0)
        meniscus_label = meniscus_labels.get(i, 0)
        labels.append([abnormal_label, acl_label, meniscus_label])

    data = np.array(data)    # (N, 1, H, W)
    labels = np.array(labels) # (N, 3)
    return data, labels

# %%
start_indices = list(range(0, 1130, 100))
end_indices = [min(start + 99, 1129) for start in start_indices]

train_data, train_labels = load_data_in_batches(start_indices, end_indices, "train")
valid_data, valid_labels = load_single_axis_mri_data("valid", 1130, 1249)

print("Train data shape:", train_data.shape)   # (N,1,H,W)
print("Train labels shape:", train_labels.shape)# (N,3)
print("Valid data shape:", valid_data.shape)
print("Valid labels shape:", valid_labels.shape)
# Out:
# Train data shape: (1130, 1, 256, 256)
# Train labels shape: (1130, 3)
# Valid data shape: (120, 1, 256, 256)
# Valid labels shape: (120, 3)

# %%
train_dataset = MRNetDataset(train_data, train_labels)
valid_dataset = MRNetDataset(valid_data, valid_labels)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=8, shuffle=False)

train_loader = MpDeviceLoader(train_loader, device)
valid_loader = MpDeviceLoader(valid_loader, device)

# %%
train_and_validate(model, train_loader, valid_loader, criterion, optimizer, epochs=20, classes=classes)
# Out:
# Epoch 1/20
# Train Loss: 0.5954 | Valid Loss: 0.7354
#
# Class: ABNORMAL
# Train Acc: 0.7965, Train ROC-AUC: 0.6530
# Valid Acc: 0.7917, Valid ROC-AUC: 0.5962
#
# Class: ACL
# Train Acc: 0.7982, Train ROC-AUC: 0.4951
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5460
#
# Class: MENISCUS
# Train Acc: 0.6274, Train ROC-AUC: 0.5626
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5263
# ---------------------------------------------------
# Epoch 2/20
# Train Loss: 0.5221 | Valid Loss: 0.7165
#
# Class: ABNORMAL
# Train Acc: 0.8071, Train ROC-AUC: 0.6860
# Valid Acc: 0.7917, Valid ROC-AUC: 0.5945
#
# Class: ACL
# Train Acc: 0.8150, Train ROC-AUC: 0.5519
# Valid Acc: 0.5417, Valid ROC-AUC: 0.4952
#
# Class: MENISCUS
# Train Acc: 0.6460, Train ROC-AUC: 0.6255
# Valid Acc: 0.6083, Valid ROC-AUC: 0.5761
# ---------------------------------------------------
# Epoch 3/20
# Train Loss: 0.5147 | Valid Loss: 0.7382
#
# Class: ABNORMAL
# Train Acc: 0.8062, Train ROC-AUC: 0.7022
# Valid Acc: 0.7917, Valid ROC-AUC: 0.5979
#
# Class: ACL
# Train Acc: 0.8159, Train ROC-AUC: 0.5738
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5752
#
# Class: MENISCUS
# Train Acc: 0.6460, Train ROC-AUC: 0.6356
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5786
# ---------------------------------------------------
# Epoch 4/20
# Train Loss: 0.4975 | Valid Loss: 0.7286
#
# Class: ABNORMAL
# Train Acc: 0.8088, Train ROC-AUC: 0.7354
# Valid Acc: 0.7917, Valid ROC-AUC: 0.5823
#
# Class: ACL
# Train Acc: 0.8159, Train ROC-AUC: 0.6337
# Valid Acc: 0.5500, Valid ROC-AUC: 0.4697
#
# Class: MENISCUS
# Train Acc: 0.6876, Train ROC-AUC: 0.6590
# Valid Acc: 0.5833, Valid ROC-AUC: 0.5667
# ---------------------------------------------------
# Epoch 5/20
# Train Loss: 0.4907 | Valid Loss: 0.8383
#
# Class: ABNORMAL
# Train Acc: 0.8062, Train ROC-AUC: 0.7251
# Valid Acc: 0.7917, Valid ROC-AUC: 0.6387
#
# Class: ACL
# Train Acc: 0.8168, Train ROC-AUC: 0.6462
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5626
#
# Class: MENISCUS
# Train Acc: 0.7071, Train ROC-AUC: 0.6745
# Valid Acc: 0.5583, Valid ROC-AUC: 0.5320
# ---------------------------------------------------
# Epoch 6/20
# Train Loss: 0.4786 | Valid Loss: 0.7869
#
# Class: ABNORMAL
# Train Acc: 0.8106, Train ROC-AUC: 0.7472
# Valid Acc: 0.7750, Valid ROC-AUC: 0.5756
#
# Class: ACL
# Train Acc: 0.8186, Train ROC-AUC: 0.6851
# Valid Acc: 0.5750, Valid ROC-AUC: 0.5382
#
# Class: MENISCUS
# Train Acc: 0.7115, Train ROC-AUC: 0.6977
# Valid Acc: 0.5750, Valid ROC-AUC: 0.5583
# ---------------------------------------------------
# Epoch 7/20
# Train Loss: 0.4647 | Valid Loss: 0.9229
#
# Class: ABNORMAL
# Train Acc: 0.8186, Train ROC-AUC: 0.7795
# Valid Acc: 0.7000, Valid ROC-AUC: 0.5844
#
# Class: ACL
# Train Acc: 0.8221, Train ROC-AUC: 0.7003
# Valid Acc: 0.5250, Valid ROC-AUC: 0.4759
#
# Class: MENISCUS
# Train Acc: 0.7310, Train ROC-AUC: 0.7108
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4966
# ---------------------------------------------------
# Epoch 8/20
# Train Loss: 0.4518 | Valid Loss: 0.7684
#
# Class: ABNORMAL
# Train Acc: 0.8230, Train ROC-AUC: 0.7845
# Valid Acc: 0.7750, Valid ROC-AUC: 0.5836
#
# Class: ACL
# Train Acc: 0.8336, Train ROC-AUC: 0.7439
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5696
#
# Class: MENISCUS
# Train Acc: 0.7257, Train ROC-AUC: 0.7412
# Valid Acc: 0.5917, Valid ROC-AUC: 0.5888
# ---------------------------------------------------
# Epoch 9/20
# Train Loss: 0.4281 | Valid Loss: 1.0300
#
# Class: ABNORMAL
# Train Acc: 0.8168, Train ROC-AUC: 0.7850
# Valid Acc: 0.7750, Valid ROC-AUC: 0.5642
#
# Class: ACL
# Train Acc: 0.8381, Train ROC-AUC: 0.7796
# Valid Acc: 0.4250, Valid ROC-AUC: 0.4071
#
# Class: MENISCUS
# Train Acc: 0.7752, Train ROC-AUC: 0.7790
# Valid Acc: 0.6000, Valid ROC-AUC: 0.5628
# ---------------------------------------------------
# Epoch 10/20
# Train Loss: 0.4051 | Valid Loss: 1.2790
#
# Class: ABNORMAL
# Train Acc: 0.8354, Train ROC-AUC: 0.8366
# Valid Acc: 0.7750, Valid ROC-AUC: 0.5629
#
# Class: ACL
# Train Acc: 0.8478, Train ROC-AUC: 0.8004
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5870
#
# Class: MENISCUS
# Train Acc: 0.7814, Train ROC-AUC: 0.7884
# Valid Acc: 0.5250, Valid ROC-AUC: 0.5116
# ---------------------------------------------------
# Epoch 11/20
# Train Loss: 0.3691 | Valid Loss: 1.0378
#
# Class: ABNORMAL
# Train Acc: 0.8389, Train ROC-AUC: 0.8300
# Valid Acc: 0.7833, Valid ROC-AUC: 0.6320
#
# Class: ACL
# Train Acc: 0.8717, Train ROC-AUC: 0.8402
# Valid Acc: 0.5417, Valid ROC-AUC: 0.6296
#
# Class: MENISCUS
# Train Acc: 0.8009, Train ROC-AUC: 0.8226
# Valid Acc: 0.5750, Valid ROC-AUC: 0.5173
# ---------------------------------------------------
# Epoch 12/20
# Train Loss: 0.3586 | Valid Loss: 0.9293
#
# Class: ABNORMAL
# Train Acc: 0.8416, Train ROC-AUC: 0.8338
# Valid Acc: 0.7917, Valid ROC-AUC: 0.6008
#
# Class: ACL
# Train Acc: 0.8673, Train ROC-AUC: 0.8573
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6061
#
# Class: MENISCUS
# Train Acc: 0.8177, Train ROC-AUC: 0.8509
# Valid Acc: 0.6000, Valid ROC-AUC: 0.5503
# ---------------------------------------------------
# Epoch 13/20
# Train Loss: 0.3164 | Valid Loss: 1.1704
#
# Class: ABNORMAL
# Train Acc: 0.8584, Train ROC-AUC: 0.8683
# Valid Acc: 0.7750, Valid ROC-AUC: 0.5579
#
# Class: ACL
# Train Acc: 0.8903, Train ROC-AUC: 0.8749
# Valid Acc: 0.5417, Valid ROC-AUC: 0.6512
#
# Class: MENISCUS
# Train Acc: 0.8487, Train ROC-AUC: 0.8795
# Valid Acc: 0.5917, Valid ROC-AUC: 0.5099
# ---------------------------------------------------
# Epoch 14/20
# Train Loss: 0.3137 | Valid Loss: 1.0274
#
# Class: ABNORMAL
# Train Acc: 0.8593, Train ROC-AUC: 0.8635
# Valid Acc: 0.7500, Valid ROC-AUC: 0.6051
#
# Class: ACL
# Train Acc: 0.8920, Train ROC-AUC: 0.8831
# Valid Acc: 0.5167, Valid ROC-AUC: 0.5606
#
# Class: MENISCUS
# Train Acc: 0.8354, Train ROC-AUC: 0.8760
# Valid Acc: 0.6000, Valid ROC-AUC: 0.5568
# ---------------------------------------------------
# Epoch 15/20
# Train Loss: 0.3171 | Valid Loss: 1.1708
#
# Class: ABNORMAL
# Train Acc: 0.8628, Train ROC-AUC: 0.8678
# Valid Acc: 0.7833, Valid ROC-AUC: 0.5846
#
# Class: ACL
# Train Acc: 0.8920, Train ROC-AUC: 0.8793
# Valid Acc: 0.5417, Valid ROC-AUC: 0.5937
#
# Class: MENISCUS
# Train Acc: 0.8310, Train ROC-AUC: 0.8645
# Valid Acc: 0.6000, Valid ROC-AUC: 0.5670
# ---------------------------------------------------
# Epoch 16/20
# Train Loss: 0.2967 | Valid Loss: 1.1690
#
# Class: ABNORMAL
# Train Acc: 0.8726, Train ROC-AUC: 0.8886
# Valid Acc: 0.7833, Valid ROC-AUC: 0.5848
#
# Class: ACL
# Train Acc: 0.9009, Train ROC-AUC: 0.8953
# Valid Acc: 0.5583, Valid ROC-AUC: 0.5816
#
# Class: MENISCUS
# Train Acc: 0.8549, Train ROC-AUC: 0.8845
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5031
# ---------------------------------------------------
# Epoch 17/20
# Train Loss: 0.2918 | Valid Loss: 1.1280
#
# Class: ABNORMAL
# Train Acc: 0.8717, Train ROC-AUC: 0.8840
# Valid Acc: 0.7250, Valid ROC-AUC: 0.6055
#
# Class: ACL
# Train Acc: 0.9027, Train ROC-AUC: 0.8940
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6627
#
# Class: MENISCUS
# Train Acc: 0.8584, Train ROC-AUC: 0.8933
# Valid Acc: 0.5917, Valid ROC-AUC: 0.5215
# ---------------------------------------------------
# Epoch 18/20
# Train Loss: 0.2598 | Valid Loss: 1.2602
#
# Class: ABNORMAL
# Train Acc: 0.8743, Train ROC-AUC: 0.8947
# Valid Acc: 0.7917, Valid ROC-AUC: 0.5907
#
# Class: ACL
# Train Acc: 0.9071, Train ROC-AUC: 0.8985
# Valid Acc: 0.5250, Valid ROC-AUC: 0.5572
#
# Class: MENISCUS
# Train Acc: 0.8841, Train ROC-AUC: 0.9223
# Valid Acc: 0.5167, Valid ROC-AUC: 0.5201
# ---------------------------------------------------
# Epoch 19/20
# Train Loss: 0.2704 | Valid Loss: 1.1544
#
# Class: ABNORMAL
# Train Acc: 0.8752, Train ROC-AUC: 0.8859
# Valid Acc: 0.6333, Valid ROC-AUC: 0.5966
#
# Class: ACL
# Train Acc: 0.9053, Train ROC-AUC: 0.8948
# Valid Acc: 0.5917, Valid ROC-AUC: 0.6181
#
# Class: MENISCUS
# Train Acc: 0.8699, Train ROC-AUC: 0.9099
# Valid Acc: 0.6083, Valid ROC-AUC: 0.5438
# ---------------------------------------------------
# Epoch 20/20
# Train Loss: 0.2576 | Valid Loss: 1.1965
#
# Class: ABNORMAL
# Train Acc: 0.8673, Train ROC-AUC: 0.8731
# Valid Acc: 0.7917, Valid ROC-AUC: 0.6177
#
# Class: ACL
# Train Acc: 0.9133, Train ROC-AUC: 0.9120
# Valid Acc: 0.5500, Valid ROC-AUC: 0.6089
#
# Class: MENISCUS
# Train Acc: 0.8761, Train ROC-AUC: 0.9197
# Valid Acc: 0.5833, Valid ROC-AUC: 0.5260
# ---------------------------------------------------

# %% [markdown]
# Now, Sagittal axes

# %%
def load_single_axis_mri_data(data_type="train", start_idx=0, end_idx=9, target_shape=(48, 256, 256)):
    data_path = train_path if data_type == "train" else valid_path
    abnormal_labels = train_abnormal if data_type == "train" else valid_abnormal
    acl_labels = train_acl if data_type == "train" else valid_acl
    meniscus_labels = train_meniscus if data_type == "train" else valid_meniscus

    data = []
    labels = []

    for i in range(start_idx, end_idx + 1):
        file_name = f"{i:04}.npy"
        scan = np.load(Path(data_path) / "sagittal" / file_name)
        scan = pad_or_crop_scan(scan, target_shape)

        # Convert 3D (D,H,W) to 2D by taking the middle slice
        d = scan.shape[0]
        mid_slice = d // 2
        single_slice = scan[mid_slice, :, :]  # shape (H, W)

        # Add channel dimension: (1, H, W)
        single_slice = np.expand_dims(single_slice, axis=0)
        data.append(single_slice)  # will become (1,H,W)

        # Labels: [abnormal, acl, meniscus]
        abnormal_label = abnormal_labels.get(i, 0)
        acl_label = acl_labels.get(i, 0)
        meniscus_label = meniscus_labels.get(i, 0)
        labels.append([abnormal_label, acl_label, meniscus_label])

    data = np.array(data)    # (N, 1, H, W)
    labels = np.array(labels) # (N, 3)
    return data, labels

# %%
start_indices = list(range(0, 1130, 100))
end_indices = [min(start + 99, 1129) for start in start_indices]

train_data, train_labels = load_data_in_batches(start_indices, end_indices, "train")
valid_data, valid_labels = load_single_axis_mri_data("valid", 1130, 1249)

print("Train data shape:", train_data.shape)   # (N,1,H,W)
print("Train labels shape:", train_labels.shape)# (N,3)
print("Valid data shape:", valid_data.shape)
print("Valid labels shape:", valid_labels.shape)
# Out:
# Train data shape: (1130, 1, 256, 256)
# Train labels shape: (1130, 3)
# Valid data shape: (120, 1, 256, 256)
# Valid labels shape: (120, 3)

# %%
train_dataset = MRNetDataset(train_data, train_labels)
valid_dataset = MRNetDataset(valid_data, valid_labels)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=8, shuffle=False)

train_loader = MpDeviceLoader(train_loader, device)
valid_loader = MpDeviceLoader(valid_loader, device)

# %%
train_and_validate(model, train_loader, valid_loader, criterion, optimizer, epochs=20, classes=classes)
# Out:
# Epoch 1/20
# Train Loss: 0.5977 | Valid Loss: 0.6508
#
# Class: ABNORMAL
# Train Acc: 0.7938, Train ROC-AUC: 0.6613
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7322
#
# Class: ACL
# Train Acc: 0.8062, Train ROC-AUC: 0.5622
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5342
#
# Class: MENISCUS
# Train Acc: 0.6204, Train ROC-AUC: 0.5681
# Valid Acc: 0.6583, Valid ROC-AUC: 0.6867
# ---------------------------------------------------
# Epoch 2/20
# Train Loss: 0.4882 | Valid Loss: 0.7269
#
# Class: ABNORMAL
# Train Acc: 0.8088, Train ROC-AUC: 0.7606
# Valid Acc: 0.7750, Valid ROC-AUC: 0.7213
#
# Class: ACL
# Train Acc: 0.8159, Train ROC-AUC: 0.6875
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5800
#
# Class: MENISCUS
# Train Acc: 0.6735, Train ROC-AUC: 0.6641
# Valid Acc: 0.6083, Valid ROC-AUC: 0.6643
# ---------------------------------------------------
# Epoch 3/20
# Train Loss: 0.4537 | Valid Loss: 0.6917
#
# Class: ABNORMAL
# Train Acc: 0.8212, Train ROC-AUC: 0.8072
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7663
#
# Class: ACL
# Train Acc: 0.8372, Train ROC-AUC: 0.7508
# Valid Acc: 0.6000, Valid ROC-AUC: 0.6232
#
# Class: MENISCUS
# Train Acc: 0.7133, Train ROC-AUC: 0.7127
# Valid Acc: 0.6083, Valid ROC-AUC: 0.5857
# ---------------------------------------------------
# Epoch 4/20
# Train Loss: 0.4027 | Valid Loss: 0.8212
#
# Class: ABNORMAL
# Train Acc: 0.8336, Train ROC-AUC: 0.8566
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7284
#
# Class: ACL
# Train Acc: 0.8584, Train ROC-AUC: 0.8324
# Valid Acc: 0.5417, Valid ROC-AUC: 0.5238
#
# Class: MENISCUS
# Train Acc: 0.7566, Train ROC-AUC: 0.7631
# Valid Acc: 0.6167, Valid ROC-AUC: 0.6606
# ---------------------------------------------------
# Epoch 5/20
# Train Loss: 0.3378 | Valid Loss: 0.8383
#
# Class: ABNORMAL
# Train Acc: 0.8602, Train ROC-AUC: 0.9028
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7781
#
# Class: ACL
# Train Acc: 0.8832, Train ROC-AUC: 0.8729
# Valid Acc: 0.5250, Valid ROC-AUC: 0.5314
#
# Class: MENISCUS
# Train Acc: 0.8044, Train ROC-AUC: 0.8538
# Valid Acc: 0.6083, Valid ROC-AUC: 0.6225
# ---------------------------------------------------
# Epoch 6/20
# Train Loss: 0.2826 | Valid Loss: 1.0074
#
# Class: ABNORMAL
# Train Acc: 0.8699, Train ROC-AUC: 0.9177
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7322
#
# Class: ACL
# Train Acc: 0.9009, Train ROC-AUC: 0.9113
# Valid Acc: 0.6083, Valid ROC-AUC: 0.5909
#
# Class: MENISCUS
# Train Acc: 0.8540, Train ROC-AUC: 0.9067
# Valid Acc: 0.6000, Valid ROC-AUC: 0.5922
# ---------------------------------------------------
# Epoch 7/20
# Train Loss: 0.2616 | Valid Loss: 1.2425
#
# Class: ABNORMAL
# Train Acc: 0.8858, Train ROC-AUC: 0.9340
# Valid Acc: 0.8083, Valid ROC-AUC: 0.7474
#
# Class: ACL
# Train Acc: 0.9106, Train ROC-AUC: 0.8993
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5129
#
# Class: MENISCUS
# Train Acc: 0.8752, Train ROC-AUC: 0.9227
# Valid Acc: 0.6583, Valid ROC-AUC: 0.6423
# ---------------------------------------------------
# Epoch 8/20
# Train Loss: 0.2259 | Valid Loss: 1.3963
#
# Class: ABNORMAL
# Train Acc: 0.8894, Train ROC-AUC: 0.9329
# Valid Acc: 0.7750, Valid ROC-AUC: 0.7013
#
# Class: ACL
# Train Acc: 0.9221, Train ROC-AUC: 0.9350
# Valid Acc: 0.5583, Valid ROC-AUC: 0.5415
#
# Class: MENISCUS
# Train Acc: 0.8947, Train ROC-AUC: 0.9382
# Valid Acc: 0.5917, Valid ROC-AUC: 0.4859
# ---------------------------------------------------
# Epoch 9/20
# Train Loss: 0.2175 | Valid Loss: 1.1793
#
# Class: ABNORMAL
# Train Acc: 0.8929, Train ROC-AUC: 0.9393
# Valid Acc: 0.7750, Valid ROC-AUC: 0.7267
#
# Class: ACL
# Train Acc: 0.9274, Train ROC-AUC: 0.9421
# Valid Acc: 0.5750, Valid ROC-AUC: 0.5340
#
# Class: MENISCUS
# Train Acc: 0.8982, Train ROC-AUC: 0.9425
# Valid Acc: 0.5833, Valid ROC-AUC: 0.5158
# ---------------------------------------------------
# Epoch 10/20
# Train Loss: 0.2252 | Valid Loss: 1.1913
#
# Class: ABNORMAL
# Train Acc: 0.8823, Train ROC-AUC: 0.9240
# Valid Acc: 0.8083, Valid ROC-AUC: 0.7423
#
# Class: ACL
# Train Acc: 0.9301, Train ROC-AUC: 0.9406
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5334
#
# Class: MENISCUS
# Train Acc: 0.9097, Train ROC-AUC: 0.9441
# Valid Acc: 0.6250, Valid ROC-AUC: 0.6041
# ---------------------------------------------------
# Epoch 11/20
# Train Loss: 0.1983 | Valid Loss: 1.2867
#
# Class: ABNORMAL
# Train Acc: 0.8938, Train ROC-AUC: 0.9384
# Valid Acc: 0.8083, Valid ROC-AUC: 0.7274
#
# Class: ACL
# Train Acc: 0.9265, Train ROC-AUC: 0.9329
# Valid Acc: 0.5000, Valid ROC-AUC: 0.5255
#
# Class: MENISCUS
# Train Acc: 0.9212, Train ROC-AUC: 0.9601
# Valid Acc: 0.6250, Valid ROC-AUC: 0.5549
# ---------------------------------------------------
# Epoch 12/20
# Train Loss: 0.2072 | Valid Loss: 1.2460
#
# Class: ABNORMAL
# Train Acc: 0.8841, Train ROC-AUC: 0.9286
# Valid Acc: 0.8000, Valid ROC-AUC: 0.7305
#
# Class: ACL
# Train Acc: 0.9345, Train ROC-AUC: 0.9593
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5415
#
# Class: MENISCUS
# Train Acc: 0.8991, Train ROC-AUC: 0.9501
# Valid Acc: 0.6333, Valid ROC-AUC: 0.4878
# ---------------------------------------------------
# Epoch 13/20
# Train Loss: 0.1972 | Valid Loss: 1.8682
#
# Class: ABNORMAL
# Train Acc: 0.8965, Train ROC-AUC: 0.9433
# Valid Acc: 0.8167, Valid ROC-AUC: 0.7724
#
# Class: ACL
# Train Acc: 0.9372, Train ROC-AUC: 0.9520
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5453
#
# Class: MENISCUS
# Train Acc: 0.9027, Train ROC-AUC: 0.9516
# Valid Acc: 0.6167, Valid ROC-AUC: 0.5404
# ---------------------------------------------------
# Epoch 14/20
# Train Loss: 0.1905 | Valid Loss: 1.8965
#
# Class: ABNORMAL
# Train Acc: 0.8956, Train ROC-AUC: 0.9381
# Valid Acc: 0.8000, Valid ROC-AUC: 0.7312
#
# Class: ACL
# Train Acc: 0.9398, Train ROC-AUC: 0.9529
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5053
#
# Class: MENISCUS
# Train Acc: 0.9115, Train ROC-AUC: 0.9537
# Valid Acc: 0.5833, Valid ROC-AUC: 0.4038
# ---------------------------------------------------
# Epoch 15/20
# Train Loss: 0.1983 | Valid Loss: 1.5621
#
# Class: ABNORMAL
# Train Acc: 0.8894, Train ROC-AUC: 0.9259
# Valid Acc: 0.7833, Valid ROC-AUC: 0.7440
#
# Class: ACL
# Train Acc: 0.9398, Train ROC-AUC: 0.9515
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5530
#
# Class: MENISCUS
# Train Acc: 0.9168, Train ROC-AUC: 0.9527
# Valid Acc: 0.6250, Valid ROC-AUC: 0.5215
# ---------------------------------------------------
# Epoch 16/20
# Train Loss: 0.1828 | Valid Loss: 1.6685
#
# Class: ABNORMAL
# Train Acc: 0.8947, Train ROC-AUC: 0.9351
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7339
#
# Class: ACL
# Train Acc: 0.9363, Train ROC-AUC: 0.9546
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5490
#
# Class: MENISCUS
# Train Acc: 0.9274, Train ROC-AUC: 0.9622
# Valid Acc: 0.5917, Valid ROC-AUC: 0.4743
# ---------------------------------------------------
# Epoch 17/20
# Train Loss: 0.1809 | Valid Loss: 1.4756
#
# Class: ABNORMAL
# Train Acc: 0.8929, Train ROC-AUC: 0.9270
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7764
#
# Class: ACL
# Train Acc: 0.9407, Train ROC-AUC: 0.9523
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5264
#
# Class: MENISCUS
# Train Acc: 0.9257, Train ROC-AUC: 0.9622
# Valid Acc: 0.6000, Valid ROC-AUC: 0.5447
# ---------------------------------------------------
# Epoch 18/20
# Train Loss: 0.1883 | Valid Loss: 1.5667
#
# Class: ABNORMAL
# Train Acc: 0.8929, Train ROC-AUC: 0.9354
# Valid Acc: 0.7417, Valid ROC-AUC: 0.7196
#
# Class: ACL
# Train Acc: 0.9327, Train ROC-AUC: 0.9489
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5196
#
# Class: MENISCUS
# Train Acc: 0.9212, Train ROC-AUC: 0.9609
# Valid Acc: 0.6250, Valid ROC-AUC: 0.6080
# ---------------------------------------------------
# Epoch 19/20
# Train Loss: 0.1666 | Valid Loss: 1.5243
#
# Class: ABNORMAL
# Train Acc: 0.8956, Train ROC-AUC: 0.9384
# Valid Acc: 0.7917, Valid ROC-AUC: 0.7398
#
# Class: ACL
# Train Acc: 0.9442, Train ROC-AUC: 0.9549
# Valid Acc: 0.5750, Valid ROC-AUC: 0.5544
#
# Class: MENISCUS
# Train Acc: 0.9345, Train ROC-AUC: 0.9691
# Valid Acc: 0.6333, Valid ROC-AUC: 0.5229
# ---------------------------------------------------
# Epoch 20/20
# Train Loss: 0.1694 | Valid Loss: 1.5397
#
# Class: ABNORMAL
# Train Acc: 0.8956, Train ROC-AUC: 0.9384
# Valid Acc: 0.7750, Valid ROC-AUC: 0.7122
#
# Class: ACL
# Train Acc: 0.9434, Train ROC-AUC: 0.9562
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5582
#
# Class: MENISCUS
# Train Acc: 0.9319, Train ROC-AUC: 0.9663
# Valid Acc: 0.6333, Valid ROC-AUC: 0.5894
# ---------------------------------------------------

# %% [markdown]
# # 1. Performance Analysis of Current Views with ResNet-18
#
# ## Axial View
#
# ### Final Epoch Metrics (Epoch 20/20)
#
# | Metric         | Value  |
# |----------------|--------|
# | **Train Loss** | 0.1882 |
# | **Valid Loss** | 1.8368 |
#
# ### ABNORMAL
#
# | Metric            | Value  |
# |-------------------|--------|
# | **Train Acc**     | 0.9133 |
# | **Train ROC-AUC** | 0.9616 |
# | **Valid Acc**     | 0.8000 |
# | **Valid ROC-AUC** | 0.7596 |
#
# ### ACL
#
# | Metric            | Value  |
# |-------------------|--------|
# | **Train Acc**     | 0.9531 |
# | **Train ROC-AUC** | 0.9751 |
# | **Valid Acc**     | 0.5667 |
# | **Valid ROC-AUC** | 0.5835 |
#
# ### MENISCUS
#
# | Metric            | Value  |
# |-------------------|--------|
# | **Train Acc**     | 0.9009 |
# | **Train ROC-AUC** | 0.9599 |
# | **Valid Acc**     | 0.5417 |
# | **Valid ROC-AUC** | 0.6202 |
#
# ## Sagittal View
#
# ### Final Epoch Metrics (Epoch 20/20)
#
# | Metric         | Value  |
# |----------------|--------|
# | **Train Loss** | 0.2576 |
# | **Valid Loss** | 1.1965 |
#
# ### ABNORMAL
#
# | Metric            | Value  |
# |-------------------|--------|
# | **Train Acc**     | 0.8673 |
# | **Train ROC-AUC** | 0.8731 |
# | **Valid Acc**     | 0.7917 |
# | **Valid ROC-AUC** | 0.6177 |
#
# ### ACL
#
# | Metric            | Value  |
# |-------------------|--------|
# | **Train Acc**     | 0.9133 |
# | **Train ROC-AUC** | 0.9120 |
# | **Valid Acc**     | 0.5667 |
# | **Valid ROC-AUC** | 0.6089 |
#
# ### MENISCUS
#
# | Metric            | Value  |
# |-------------------|--------|
# | **Train Acc**     | 0.8761 |
# | **Train ROC-AUC** | 0.9663 |
# | **Valid Acc**     | 0.5833 |
# | **Valid ROC-AUC** | 0.5894 |
#
# ## Coronal View
#
# ### Final Epoch Metrics (Epoch 20/20)
#
# | Metric         | Value  |
# |----------------|--------|
# | **Train Loss** | 0.2576 |
# | **Valid Loss** | 1.1965 |
#
# ### ABNORMAL
#
# | Metric            | Value  |
# |-------------------|--------|
# | **Train Acc**     | 0.8673 |
# | **Train ROC-AUC** | 0.8731 |
# | **Valid Acc**     | 0.7917 |
# | **Valid ROC-AUC** | 0.6177 |
#
# ### ACL
#
# | Metric            | Value  |
# |-------------------|--------|
# | **Train Acc**     | 0.9133 |
# | **Train ROC-AUC** | 0.9120 |
# | **Valid Acc**     | 0.5667 |
# | **Valid ROC-AUC** | 0.6089 |
#
# ### MENISCUS
#
# | Metric            | Value  |
# |-------------------|--------|
# | **Train Acc**     | 0.8761 |
# | **Train ROC-AUC** | 0.9663 |
# | **Valid Acc**     | 0.5833 |
# | **Valid ROC-AUC** | 0.5894 |
#
# # 2. Why Choose the Axial View for ResNet-50?
#
# ## a. Superior Performance Metrics
#
# ### ABNORMAL Class
# - **Axial view** achieved the highest **Train ROC-AUC (0.9616)** and **Valid ROC-AUC (0.7596)** compared to sagittal and coronal views.
#
# ### ACL Class
# - While **axial view** has a high **Train ROC-AUC (0.9751)**, the **Valid ROC-AUC (0.5835)** indicates room for improvement. However, it still outperforms the coronal view's **Valid ROC-AUC (~0.6)** and is comparable to the sagittal view.
#
# ### MENISCUS Class
# - **Axial view** shows a high **Train ROC-AUC (0.9599)** and a moderate **Valid ROC-AUC (0.6202)**, which is better than the coronal view and comparable to the sagittal view.
#
# ## b. Consistency and Feature Richness
# - The **axial view** likely captures more discriminative anatomical features relevant to your classification tasks. This is evident from the higher ROC-AUC scores in critical classes.
# - **Axial scans** provide a top-down view, which might be more informative for detecting abnormalities, ACL injuries, and meniscus issues compared to other views.
#
# ## c. Potential for Better Generalization with ResNet-50
# - **ResNet-50** is a deeper architecture with more parameters, which can potentially capture more complex patterns and improve performance, especially in scenarios where the current model shows promising results but has room to grow.
# - Given that **ResNet-18** already performs relatively well on the axial view, **ResNet-50** can leverage its increased capacity to further enhance feature extraction and classification performance.
#
# ---
#
# We will now try **ResNet50** to explore its effectiveness and potentially reduce overfitting while maintaining strong performance metrics.

# %%
class SingleChannelResNet50(nn.Module):
    def __init__(self, num_classes=3, pretrained=True):
        super(SingleChannelResNet50, self).__init__()
        # Initialize the ResNet-50 model
        self.model = resnet50()

        # Modify the first convolutional layer to accept 1-channel input
        original_conv1 = self.model.conv1
        self.model.conv1 = nn.Conv2d(
            in_channels=1,
            out_channels=original_conv1.out_channels,
            kernel_size=original_conv1.kernel_size,
            stride=original_conv1.stride,
            padding=original_conv1.padding,
            bias=original_conv1.bias
        )

        # Initialize the new conv1 weights
        if pretrained:
            with torch.no_grad():
                # Average the weights across the original RGB channels to initialize the single channel
                self.model.conv1.weight = nn.Parameter(original_conv1.weight.sum(dim=1, keepdim=True))

        # Replace the final fully connected layer to output `num_classes` logits
        in_features = self.model.fc.in_features
        self.model.fc = nn.Linear(in_features, num_classes)

    def forward(self, x):
        return self.model(x)

# %%
def load_single_axis_mri_data(data_type="train", start_idx=0, end_idx=9, target_shape=(48, 256, 256)):
    data_path = train_path if data_type == "train" else valid_path
    abnormal_labels = train_abnormal if data_type == "train" else valid_abnormal
    acl_labels = train_acl if data_type == "train" else valid_acl
    meniscus_labels = train_meniscus if data_type == "train" else valid_meniscus

    data = []
    labels = []

    for i in range(start_idx, end_idx + 1):
        file_name = f"{i:04}.npy"
        scan = np.load(Path(data_path) / "axial" / file_name)
        scan = pad_or_crop_scan(scan, target_shape)

        # Convert 3D (D,H,W) to 2D by taking the middle slice
        d = scan.shape[0]
        mid_slice = d // 2
        single_slice = scan[mid_slice, :, :]  # shape (H, W)

        # Add channel dimension: (1, H, W)
        single_slice = np.expand_dims(single_slice, axis=0)
        data.append(single_slice)  # will become (1,H,W)

        # Labels: [abnormal, acl, meniscus]
        abnormal_label = abnormal_labels.get(i, 0)
        acl_label = acl_labels.get(i, 0)
        meniscus_label = meniscus_labels.get(i, 0)
        labels.append([abnormal_label, acl_label, meniscus_label])

    data = np.array(data)    # (N, 1, H, W)
    labels = np.array(labels) # (N, 3)
    return data, labels

# %%
start_indices = list(range(0, 1130, 100))
end_indices = [min(start + 99, 1129) for start in start_indices]

train_data, train_labels = load_data_in_batches(start_indices, end_indices, "train")
valid_data, valid_labels = load_single_axis_mri_data("valid", 1130, 1249)

print("Train data shape:", train_data.shape)   # (N,1,H,W)
print("Train labels shape:", train_labels.shape)# (N,3)
print("Valid data shape:", valid_data.shape)
print("Valid labels shape:", valid_labels.shape)
# Out:
# Train data shape: (1130, 1, 256, 256)
# Train labels shape: (1130, 3)
# Valid data shape: (120, 1, 256, 256)
# Valid labels shape: (120, 3)

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model = SingleChannelResNet50(num_classes=3).to(device)

# %%
train_and_validate(model, train_loader, valid_loader, criterion, optimizer, epochs=20, classes=classes)
# Out:
# Epoch 1/20
# Train Loss: 0.6417 | Valid Loss: 0.6687
#
# Class: ABNORMAL
# Train Acc: 0.7133, Train ROC-AUC: 0.6898
# Valid Acc: 0.7167, Valid ROC-AUC: 0.6261
#
# Class: ACL
# Train Acc: 0.7938, Train ROC-AUC: 0.4604
# Valid Acc: 0.5333, Valid ROC-AUC: 0.4826
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5943
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6852
# ---------------------------------------------------
# Epoch 2/20
# Train Loss: 0.6431 | Valid Loss: 0.6706
#
# Class: ABNORMAL
# Train Acc: 0.7071, Train ROC-AUC: 0.6734
# Valid Acc: 0.7000, Valid ROC-AUC: 0.6278
#
# Class: ACL
# Train Acc: 0.7929, Train ROC-AUC: 0.4694
# Valid Acc: 0.5500, Valid ROC-AUC: 0.4717
#
# Class: MENISCUS
# Train Acc: 0.6496, Train ROC-AUC: 0.5682
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6547
# ---------------------------------------------------
# Epoch 3/20
# Train Loss: 0.6428 | Valid Loss: 0.6709
#
# Class: ABNORMAL
# Train Acc: 0.7035, Train ROC-AUC: 0.6707
# Valid Acc: 0.7167, Valid ROC-AUC: 0.6291
#
# Class: ACL
# Train Acc: 0.8009, Train ROC-AUC: 0.4646
# Valid Acc: 0.5083, Valid ROC-AUC: 0.5028
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5617
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6462
# ---------------------------------------------------
# Epoch 4/20
# Train Loss: 0.6419 | Valid Loss: 0.6692
#
# Class: ABNORMAL
# Train Acc: 0.6965, Train ROC-AUC: 0.6804
# Valid Acc: 0.7167, Valid ROC-AUC: 0.6253
#
# Class: ACL
# Train Acc: 0.7903, Train ROC-AUC: 0.4707
# Valid Acc: 0.5417, Valid ROC-AUC: 0.5264
#
# Class: MENISCUS
# Train Acc: 0.6469, Train ROC-AUC: 0.5825
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6637
# ---------------------------------------------------
# Epoch 5/20
# Train Loss: 0.6439 | Valid Loss: 0.6648
#
# Class: ABNORMAL
# Train Acc: 0.7035, Train ROC-AUC: 0.6642
# Valid Acc: 0.7333, Valid ROC-AUC: 0.6366
#
# Class: ACL
# Train Acc: 0.7912, Train ROC-AUC: 0.4595
# Valid Acc: 0.5000, Valid ROC-AUC: 0.4422
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5572
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6307
# ---------------------------------------------------
# Epoch 6/20
# Train Loss: 0.6420 | Valid Loss: 0.6679
#
# Class: ABNORMAL
# Train Acc: 0.6903, Train ROC-AUC: 0.6825
# Valid Acc: 0.7083, Valid ROC-AUC: 0.6215
#
# Class: ACL
# Train Acc: 0.7929, Train ROC-AUC: 0.4540
# Valid Acc: 0.4750, Valid ROC-AUC: 0.4293
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5765
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6490
# ---------------------------------------------------
# Epoch 7/20
# Train Loss: 0.6418 | Valid Loss: 0.6694
#
# Class: ABNORMAL
# Train Acc: 0.7018, Train ROC-AUC: 0.6807
# Valid Acc: 0.7167, Valid ROC-AUC: 0.5992
#
# Class: ACL
# Train Acc: 0.7920, Train ROC-AUC: 0.4550
# Valid Acc: 0.5417, Valid ROC-AUC: 0.4776
#
# Class: MENISCUS
# Train Acc: 0.6469, Train ROC-AUC: 0.5828
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6160
# ---------------------------------------------------
# Epoch 8/20
# Train Loss: 0.6422 | Valid Loss: 0.6702
#
# Class: ABNORMAL
# Train Acc: 0.6973, Train ROC-AUC: 0.6806
# Valid Acc: 0.7083, Valid ROC-AUC: 0.6274
#
# Class: ACL
# Train Acc: 0.8027, Train ROC-AUC: 0.4766
# Valid Acc: 0.5333, Valid ROC-AUC: 0.5014
#
# Class: MENISCUS
# Train Acc: 0.6496, Train ROC-AUC: 0.5679
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6646
# ---------------------------------------------------
# Epoch 9/20
# Train Loss: 0.6435 | Valid Loss: 0.6656
#
# Class: ABNORMAL
# Train Acc: 0.7009, Train ROC-AUC: 0.6660
# Valid Acc: 0.7250, Valid ROC-AUC: 0.6375
#
# Class: ACL
# Train Acc: 0.7894, Train ROC-AUC: 0.4623
# Valid Acc: 0.5250, Valid ROC-AUC: 0.5281
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5576
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6513
# ---------------------------------------------------
# Epoch 10/20
# Train Loss: 0.6431 | Valid Loss: 0.6678
#
# Class: ABNORMAL
# Train Acc: 0.6938, Train ROC-AUC: 0.6576
# Valid Acc: 0.7250, Valid ROC-AUC: 0.6349
#
# Class: ACL
# Train Acc: 0.7982, Train ROC-AUC: 0.4654
# Valid Acc: 0.5333, Valid ROC-AUC: 0.5000
#
# Class: MENISCUS
# Train Acc: 0.6496, Train ROC-AUC: 0.5819
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6298
# ---------------------------------------------------
# Epoch 11/20
# Train Loss: 0.6441 | Valid Loss: 0.6648
#
# Class: ABNORMAL
# Train Acc: 0.7053, Train ROC-AUC: 0.6574
# Valid Acc: 0.7167, Valid ROC-AUC: 0.6387
#
# Class: ACL
# Train Acc: 0.7903, Train ROC-AUC: 0.4628
# Valid Acc: 0.5167, Valid ROC-AUC: 0.5314
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5725
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6140
# ---------------------------------------------------
# Epoch 12/20
# Train Loss: 0.6430 | Valid Loss: 0.6675
#
# Class: ABNORMAL
# Train Acc: 0.7133, Train ROC-AUC: 0.6796
# Valid Acc: 0.7000, Valid ROC-AUC: 0.6371
#
# Class: ACL
# Train Acc: 0.8009, Train ROC-AUC: 0.4585
# Valid Acc: 0.4917, Valid ROC-AUC: 0.5070
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5800
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6584
# ---------------------------------------------------
# Epoch 13/20
# Train Loss: 0.6417 | Valid Loss: 0.6693
#
# Class: ABNORMAL
# Train Acc: 0.6982, Train ROC-AUC: 0.6871
# Valid Acc: 0.7083, Valid ROC-AUC: 0.6198
#
# Class: ACL
# Train Acc: 0.7929, Train ROC-AUC: 0.4566
# Valid Acc: 0.5250, Valid ROC-AUC: 0.5090
#
# Class: MENISCUS
# Train Acc: 0.6504, Train ROC-AUC: 0.5892
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6411
# ---------------------------------------------------
# Epoch 14/20
# Train Loss: 0.6421 | Valid Loss: 0.6705
#
# Class: ABNORMAL
# Train Acc: 0.7124, Train ROC-AUC: 0.6841
# Valid Acc: 0.7250, Valid ROC-AUC: 0.6261
#
# Class: ACL
# Train Acc: 0.8000, Train ROC-AUC: 0.4740
# Valid Acc: 0.5333, Valid ROC-AUC: 0.4694
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5874
# Valid Acc: 0.5583, Valid ROC-AUC: 0.6482
# ---------------------------------------------------
# Epoch 15/20
# Train Loss: 0.6419 | Valid Loss: 0.6659
#
# Class: ABNORMAL
# Train Acc: 0.7115, Train ROC-AUC: 0.6910
# Valid Acc: 0.7250, Valid ROC-AUC: 0.6248
#
# Class: ACL
# Train Acc: 0.7956, Train ROC-AUC: 0.4666
# Valid Acc: 0.5333, Valid ROC-AUC: 0.5342
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5762
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6711
# ---------------------------------------------------
# Epoch 16/20
# Train Loss: 0.6428 | Valid Loss: 0.6711
#
# Class: ABNORMAL
# Train Acc: 0.7062, Train ROC-AUC: 0.6781
# Valid Acc: 0.7167, Valid ROC-AUC: 0.6227
#
# Class: ACL
# Train Acc: 0.7973, Train ROC-AUC: 0.4780
# Valid Acc: 0.5000, Valid ROC-AUC: 0.4447
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5709
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5993
# ---------------------------------------------------
# Epoch 17/20
# Train Loss: 0.6433 | Valid Loss: 0.6670
#
# Class: ABNORMAL
# Train Acc: 0.6938, Train ROC-AUC: 0.6679
# Valid Acc: 0.7083, Valid ROC-AUC: 0.6316
#
# Class: ACL
# Train Acc: 0.7965, Train ROC-AUC: 0.4432
# Valid Acc: 0.5333, Valid ROC-AUC: 0.5149
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5808
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6589
# ---------------------------------------------------
# Epoch 18/20
# Train Loss: 0.6414 | Valid Loss: 0.6685
#
# Class: ABNORMAL
# Train Acc: 0.7000, Train ROC-AUC: 0.6809
# Valid Acc: 0.7083, Valid ROC-AUC: 0.6312
#
# Class: ACL
# Train Acc: 0.7991, Train ROC-AUC: 0.4927
# Valid Acc: 0.5250, Valid ROC-AUC: 0.5166
#
# Class: MENISCUS
# Train Acc: 0.6478, Train ROC-AUC: 0.5851
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6298
# ---------------------------------------------------
# Epoch 19/20
# Train Loss: 0.6420 | Valid Loss: 0.6676
#
# Class: ABNORMAL
# Train Acc: 0.6938, Train ROC-AUC: 0.6803
# Valid Acc: 0.7083, Valid ROC-AUC: 0.6139
#
# Class: ACL
# Train Acc: 0.8053, Train ROC-AUC: 0.4785
# Valid Acc: 0.5250, Valid ROC-AUC: 0.5283
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5730
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6140
# ---------------------------------------------------
# Epoch 20/20
# Train Loss: 0.6432 | Valid Loss: 0.6661
#
# Class: ABNORMAL
# Train Acc: 0.7000, Train ROC-AUC: 0.6818
# Valid Acc: 0.7167, Valid ROC-AUC: 0.6341
#
# Class: ACL
# Train Acc: 0.7912, Train ROC-AUC: 0.4585
# Valid Acc: 0.5167, Valid ROC-AUC: 0.4902
#
# Class: MENISCUS
# Train Acc: 0.6478, Train ROC-AUC: 0.5719
# Valid Acc: 0.5667, Valid ROC-AUC: 0.6377
# ---------------------------------------------------

# %% [markdown]
# # Summary of Results
#
# ## 1. ResNet-18 on Axial View (Final Epoch: Epoch 20/20)
#
# **Train Loss:** 0.1882
# **Valid Loss:** 1.8368
#
# ### Class-wise Metrics
#
# #### ABNORMAL
#
# | Metric            | ResNet-18 |
# |-------------------|-----------|
# | **Train Accuracy** | 0.9133    |
# | **Train ROC-AUC** | 0.9616    |
# | **Valid Accuracy** | 0.8000    |
# | **Valid ROC-AUC** | 0.7596    |
#
# #### ACL
#
# | Metric            | ResNet-18 |
# |-------------------|-----------|
# | **Train Accuracy** | 0.9531    |
# | **Train ROC-AUC** | 0.9751    |
# | **Valid Accuracy** | 0.5667    |
# | **Valid ROC-AUC** | 0.5835    |
#
# #### MENISCUS
#
# | Metric            | ResNet-18 |
# |-------------------|-----------|
# | **Train Accuracy** | 0.9009    |
# | **Train ROC-AUC** | 0.9599    |
# | **Valid Accuracy** | 0.5417    |
# | **Valid ROC-AUC** | 0.6202    |
#
# ---
#
# ## 2. ResNet-50 on Axial View (Final Epoch: Epoch 20/20)
#
# **Train Loss:** 0.6432
# **Valid Loss:** 0.6661
#
# ### Class-wise Metrics
#
# #### ABNORMAL
#
# | Metric            | ResNet-50 |
# |-------------------|-----------|
# | **Train Accuracy** | 0.7000    |
# | **Train ROC-AUC** | 0.6818    |
# | **Valid Accuracy** | 0.7167    |
# | **Valid ROC-AUC** | 0.6341    |
#
# #### ACL
#
# | Metric            | ResNet-50 |
# |-------------------|-----------|
# | **Train Accuracy** | 0.7912    |
# | **Train ROC-AUC** | 0.4585    |
# | **Valid Accuracy** | 0.5167    |
# | **Valid ROC-AUC** | 0.4902    |
#
# #### MENISCUS
#
# | Metric            | ResNet-50 |
# |-------------------|-----------|
# | **Train Accuracy** | 0.6478    |
# | **Train ROC-AUC** | 0.5719    |
# | **Valid Accuracy** | 0.5667    |
# | **Valid ROC-AUC** | 0.6377    |
#
# ---
#
# # Detailed Comparison
#
# ## A. Loss Metrics
#
# | Metric              | ResNet-18 (Axial) | ResNet-50 (Axial) |
# |---------------------|-------------------|-------------------|
# | **Training Loss**   | 0.1882 (Lower)    | 0.6432 (Higher)   |
# | **Validation Loss** | 1.8368 (Higher)   | 0.6661 (Lower)    |
#
# **Interpretation:**
#
# - **ResNet-18** achieves a lower training loss but a higher validation loss, indicating that it fits the training data very well but may be **overfitting**, struggling to generalize to unseen data.
# - **ResNet-50** exhibits a higher training loss but a lower validation loss, suggesting that it might be **underfitting** and not capturing the underlying patterns in the data as effectively as ResNet-18.
#
# ## B. Per-Class Accuracy and ROC-AUC
#
# ### ABNORMAL Class
#
# | Metric            | ResNet-18 | ResNet-50 |
# |-------------------|-----------|-----------|
# | **Train Acc**     | 91.33%    | 70.00%    |
# | **Train ROC-AUC** | 0.9616    | 0.6818    |
# | **Valid Acc**     | 80.00%    | 71.67%    |
# | **Valid ROC-AUC** | 0.7596    | 0.6341    |
#
# **Conclusion:**
# ResNet-18 significantly outperforms ResNet-50 in both training and validation for the **ABNORMAL** class.
#
# ### ACL Class
#
# | Metric            | ResNet-18 | ResNet-50 |
# |-------------------|-----------|-----------|
# | **Train Acc**     | 95.31%    | 79.12%    |
# | **Train ROC-AUC** | 0.9751    | 0.4585    |
# | **Valid Acc**     | 56.67%    | 51.67%    |
# | **Valid ROC-AUC** | 0.5835    | 0.4902    |
#
# **Conclusion:**
# ResNet-18 shows superior performance in both accuracy and ROC-AUC for the **ACL** class compared to ResNet-50.
#
# ### MENISCUS Class
#
# | Metric            | ResNet-18 | ResNet-50 |
# |-------------------|-----------|-----------|
# | **Train Acc**     | 90.09%    | 64.78%    |
# | **Train ROC-AUC** | 0.9599    | 0.5719    |
# | **Valid Acc**     | 54.17%    | 56.67%    |
# | **Valid ROC-AUC** | 0.6202    | 0.6377    |
#
# **Conclusion:**
# While ResNet-50 shows a slight improvement in validation accuracy and ROC-AUC for the **MENISCUS** class, ResNet-18's training performance is substantially better. However, both models struggle with generalization in validation.
#
# ## C. Overall Performance
#
# - **ResNet-18:** Demonstrates higher training accuracies and ROC-AUC scores across all classes, indicating strong learning from the training data.
# - **ResNet-50:** Despite its more complex architecture, fails to generalize effectively to the validation set, as evidenced by lower ROC-AUC and comparable or slightly better validation accuracies in some classes.
#
# ## D. Potential Reasons for ResNet-50's Underperformance
#
# - **Overfitting vs. Underfitting:**
#   - **ResNet-18** might be overfitting the training data, achieving low training loss but high validation loss.
#   - **ResNet-50** appears to underfit, not capturing the data's complexities sufficiently, leading to higher training loss but slightly better validation loss.
#
# - **Training Configuration:**
#   - **Learning Rate:** ResNet-50 may require different learning rate settings. Using the same learning rate as ResNet-18 might not be optimal.
#   - **Batch Size:** Due to its larger size, ResNet-50 might benefit from different batch sizes to stabilize training.
#   - **Epochs and Early Stopping:** ResNet-50 may need more epochs or early stopping criteria to optimize its performance effectively.
#
# - **Model Complexity and Data Size:**
#   - **ResNet-50** has more parameters, requiring more data to train effectively. If the dataset isn't large enough, ResNet-50 might not utilize its capacity fully.
#
# - **Regularization Techniques:**
#   - Insufficient regularization (e.g., dropout, weight decay) can adversely affect ResNet-50's performance, leading to underfitting or overfitting.
#
# - **Initialization and Fine-Tuning:**
#   - If ResNet-50 wasn't properly initialized or fine-tuned, it might not leverage the pre-trained weights effectively.
#
# ---
#
# # Recommendations
#
# **Continue with ResNet-18 on Axial View:**
#
# Given the current performance metrics, **ResNet-18** trained on the axial view is performing better overall, especially in critical classes like **ABNORMAL** and **ACL**. It shows higher ROC-AUC scores, indicating better discriminative ability.
#
# We will now try **ResNet18** to further explore its effectiveness and potentially reduce overfitting while maintaining strong performance metrics.

# %%
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
model = SingleChannelResNet18(num_classes=3).to(device)

# %%
train_and_validate(model, train_loader, valid_loader, criterion, optimizer, epochs=20, classes=classes)
# Out:
# Epoch 1/20
# Train Loss: 0.6330 | Valid Loss: 0.6672
#
# Class: ABNORMAL
# Train Acc: 0.8000, Train ROC-AUC: 0.6401
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5815
#
# Class: ACL
# Train Acc: 0.8142, Train ROC-AUC: 0.4810
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5449
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5421
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4893
# ---------------------------------------------------
# Epoch 2/20
# Train Loss: 0.6323 | Valid Loss: 0.6650
#
# Class: ABNORMAL
# Train Acc: 0.8000, Train ROC-AUC: 0.6730
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5865
#
# Class: ACL
# Train Acc: 0.8159, Train ROC-AUC: 0.5278
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5474
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5284
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5062
# ---------------------------------------------------
# Epoch 3/20
# Train Loss: 0.6337 | Valid Loss: 0.6662
#
# Class: ABNORMAL
# Train Acc: 0.7947, Train ROC-AUC: 0.6435
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5861
#
# Class: ACL
# Train Acc: 0.8150, Train ROC-AUC: 0.4978
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5550
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.4994
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4907
# ---------------------------------------------------
# Epoch 4/20
# Train Loss: 0.6318 | Valid Loss: 0.6660
#
# Class: ABNORMAL
# Train Acc: 0.8035, Train ROC-AUC: 0.6848
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5971
#
# Class: ACL
# Train Acc: 0.8150, Train ROC-AUC: 0.5292
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5317
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5185
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5158
# ---------------------------------------------------
# Epoch 5/20
# Train Loss: 0.6334 | Valid Loss: 0.6649
#
# Class: ABNORMAL
# Train Acc: 0.8027, Train ROC-AUC: 0.6479
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5794
#
# Class: ACL
# Train Acc: 0.8150, Train ROC-AUC: 0.5329
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5474
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5132
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4847
# ---------------------------------------------------
# Epoch 6/20
# Train Loss: 0.6340 | Valid Loss: 0.6645
#
# Class: ABNORMAL
# Train Acc: 0.7929, Train ROC-AUC: 0.6467
# Valid Acc: 0.7917, Valid ROC-AUC: 0.5806
#
# Class: ACL
# Train Acc: 0.8159, Train ROC-AUC: 0.5212
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5598
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.4921
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5141
# ---------------------------------------------------
# Epoch 7/20
# Train Loss: 0.6338 | Valid Loss: 0.6654
#
# Class: ABNORMAL
# Train Acc: 0.7929, Train ROC-AUC: 0.6540
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5836
#
# Class: ACL
# Train Acc: 0.8150, Train ROC-AUC: 0.5208
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5536
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5113
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5037
# ---------------------------------------------------
# Epoch 8/20
# Train Loss: 0.6335 | Valid Loss: 0.6674
#
# Class: ABNORMAL
# Train Acc: 0.8035, Train ROC-AUC: 0.6672
# Valid Acc: 0.7917, Valid ROC-AUC: 0.5331
#
# Class: ACL
# Train Acc: 0.8133, Train ROC-AUC: 0.4806
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5744
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5243
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4375
# ---------------------------------------------------
# Epoch 9/20
# Train Loss: 0.6341 | Valid Loss: 0.6653
#
# Class: ABNORMAL
# Train Acc: 0.7920, Train ROC-AUC: 0.6325
# Valid Acc: 0.7917, Valid ROC-AUC: 0.5747
#
# Class: ACL
# Train Acc: 0.8133, Train ROC-AUC: 0.5143
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5589
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5052
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5031
# ---------------------------------------------------
# Epoch 10/20
# Train Loss: 0.6321 | Valid Loss: 0.6663
#
# Class: ABNORMAL
# Train Acc: 0.7991, Train ROC-AUC: 0.6770
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5777
#
# Class: ACL
# Train Acc: 0.8150, Train ROC-AUC: 0.5186
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5612
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5382
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4935
# ---------------------------------------------------
# Epoch 11/20
# Train Loss: 0.6334 | Valid Loss: 0.6661
#
# Class: ABNORMAL
# Train Acc: 0.7894, Train ROC-AUC: 0.6642
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5827
#
# Class: ACL
# Train Acc: 0.8142, Train ROC-AUC: 0.5027
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5390
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5182
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4890
# ---------------------------------------------------
# Epoch 12/20
# Train Loss: 0.6335 | Valid Loss: 0.6654
#
# Class: ABNORMAL
# Train Acc: 0.7991, Train ROC-AUC: 0.6356
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5802
#
# Class: ACL
# Train Acc: 0.8150, Train ROC-AUC: 0.4894
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5511
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5271
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5006
# ---------------------------------------------------
# Epoch 13/20
# Train Loss: 0.6341 | Valid Loss: 0.6727
#
# Class: ABNORMAL
# Train Acc: 0.7912, Train ROC-AUC: 0.6692
# Valid Acc: 0.7167, Valid ROC-AUC: 0.6147
#
# Class: ACL
# Train Acc: 0.8142, Train ROC-AUC: 0.5162
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5345
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.4917
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4208
# ---------------------------------------------------
# Epoch 14/20
# Train Loss: 0.6335 | Valid Loss: 0.6659
#
# Class: ABNORMAL
# Train Acc: 0.8027, Train ROC-AUC: 0.6402
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5907
#
# Class: ACL
# Train Acc: 0.8142, Train ROC-AUC: 0.5223
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5426
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5105
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5076
# ---------------------------------------------------
# Epoch 15/20
# Train Loss: 0.6328 | Valid Loss: 0.6678
#
# Class: ABNORMAL
# Train Acc: 0.8027, Train ROC-AUC: 0.6486
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5811
#
# Class: ACL
# Train Acc: 0.8142, Train ROC-AUC: 0.5346
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5572
#
# Class: MENISCUS
# Train Acc: 0.6478, Train ROC-AUC: 0.5142
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5025
# ---------------------------------------------------
# Epoch 16/20
# Train Loss: 0.6334 | Valid Loss: 0.6654
#
# Class: ABNORMAL
# Train Acc: 0.7965, Train ROC-AUC: 0.6547
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5886
#
# Class: ACL
# Train Acc: 0.8133, Train ROC-AUC: 0.5214
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5527
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5010
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5260
# ---------------------------------------------------
# Epoch 17/20
# Train Loss: 0.6335 | Valid Loss: 0.6660
#
# Class: ABNORMAL
# Train Acc: 0.8053, Train ROC-AUC: 0.6462
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5874
#
# Class: ACL
# Train Acc: 0.8142, Train ROC-AUC: 0.5000
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5673
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5211
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4751
# ---------------------------------------------------
# Epoch 18/20
# Train Loss: 0.6334 | Valid Loss: 0.6654
#
# Class: ABNORMAL
# Train Acc: 0.7929, Train ROC-AUC: 0.6457
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5836
#
# Class: ACL
# Train Acc: 0.8168, Train ROC-AUC: 0.5054
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5679
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5121
# Valid Acc: 0.5667, Valid ROC-AUC: 0.4966
# ---------------------------------------------------
# Epoch 19/20
# Train Loss: 0.6323 | Valid Loss: 0.6667
#
# Class: ABNORMAL
# Train Acc: 0.8000, Train ROC-AUC: 0.6642
# Valid Acc: 0.7250, Valid ROC-AUC: 0.6059
#
# Class: ACL
# Train Acc: 0.8150, Train ROC-AUC: 0.5150
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5362
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5335
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5291
# ---------------------------------------------------
# Epoch 20/20
# Train Loss: 0.6335 | Valid Loss: 0.6657
#
# Class: ABNORMAL
# Train Acc: 0.7912, Train ROC-AUC: 0.6481
# Valid Acc: 0.7250, Valid ROC-AUC: 0.5941
#
# Class: ACL
# Train Acc: 0.8150, Train ROC-AUC: 0.5133
# Valid Acc: 0.5500, Valid ROC-AUC: 0.5477
#
# Class: MENISCUS
# Train Acc: 0.6487, Train ROC-AUC: 0.5130
# Valid Acc: 0.5667, Valid ROC-AUC: 0.5170
# ---------------------------------------------------

# %% [markdown]
# # Summary of Results
#
# ## 1. Previous ResNet-18 on Axial View (Final Epoch: Epoch 20/20)
#
# **Train Loss:** 0.1882
# **Valid Loss:** 1.8368
#
# ### Class-wise Metrics
#
# #### ABNORMAL
#
# | Metric             | Value  |
# |--------------------|--------|
# | **Train Accuracy** | 0.9133 |
# | **Train ROC-AUC**  | 0.9616 |
# | **Valid Accuracy** | 0.8000 |
# | **Valid ROC-AUC**  | 0.7596 |
#
# #### ACL
#
# | Metric             | Value  |
# |--------------------|--------|
# | **Train Accuracy** | 0.9531 |
# | **Train ROC-AUC**  | 0.9751 |
# | **Valid Accuracy** | 0.5667 |
# | **Valid ROC-AUC**  | 0.5835 |
#
# #### MENISCUS
#
# | Metric             | Value  |
# |--------------------|--------|
# | **Train Accuracy** | 0.9009 |
# | **Train ROC-AUC**  | 0.9599 |
# | **Valid Accuracy** | 0.5417 |
# | **Valid ROC-AUC**  | 0.6202 |
#
# ---
#
# ## 2. New ResNet-18 with Learning Rate = 0.0001 on Axial View (Final Epoch: Epoch 20/20)
#
# **Train Loss:** 0.6335
# **Valid Loss:** 0.6657
#
# ### Class-wise Metrics
#
# #### ABNORMAL
#
# | Metric             | Value  |
# |--------------------|--------|
# | **Train Accuracy** | 0.7912 |
# | **Train ROC-AUC**  | 0.6481 |
# | **Valid Accuracy** | 0.7250 |
# | **Valid ROC-AUC**  | 0.5941 |
#
# #### ACL
#
# | Metric             | Value  |
# |--------------------|--------|
# | **Train Accuracy** | 0.8150 |
# | **Train ROC-AUC**  | 0.5133 |
# | **Valid Accuracy** | 0.5500 |
# | **Valid ROC-AUC**  | 0.5477 |
#
# #### MENISCUS
#
# | Metric             | Value  |
# |--------------------|--------|
# | **Train Accuracy** | 0.6487 |
# | **Train ROC-AUC**  | 0.5130 |
# | **Valid Accuracy** | 0.5667 |
# | **Valid ROC-AUC**  | 0.5170 |
#
# ---
#
# # Detailed Comparison
#
# ## A. Loss Metrics
#
# | Metric            | Previous ResNet-18 | New ResNet-18 (LR=0.0001) |
# |-------------------|--------------------|----------------------------|
# | **Training Loss** | 0.1882 (Lower)     | 0.6335 (Higher)            |
# | **Validation Loss** | 1.8368 (Higher)   | 0.6657 (Lower)             |
#
# **Interpretation:**
#
# - **Training Loss:** The previous ResNet-18 achieved a much lower training loss, indicating it fit the training data more effectively.
# - **Validation Loss:** The new ResNet-18 has a lower validation loss, which might suggest better generalization at a glance. However, this should be interpreted cautiously given the other metrics.
#
# ## B. Per-Class Accuracy and ROC-AUC
#
# ### 1. ABNORMAL Class
#
# | Metric             | Previous ResNet-18 | New ResNet-18 (LR=0.0001) |
# |--------------------|--------------------|----------------------------|
# | **Train Accuracy** | 91.33%             | 79.12%                     |
# | **Train ROC-AUC**  | 0.9616             | 0.6481                     |
# | **Valid Accuracy** | 80.00%             | 72.50%                     |
# | **Valid ROC-AUC**  | 0.7596             | 0.5941                     |
#
# **Conclusion:**
# The previous ResNet-18 significantly outperforms the new ResNet-18 in both training and validation metrics for the **ABNORMAL** class.
#
# ### 2. ACL Class
#
# | Metric             | Previous ResNet-18 | New ResNet-18 (LR=0.0001) |
# |--------------------|--------------------|----------------------------|
# | **Train Accuracy** | 95.31%             | 81.50%                     |
# | **Train ROC-AUC**  | 0.9751             | 0.5133                     |
# | **Valid Accuracy** | 56.67%             | 55.00%                     |
# | **Valid ROC-AUC**  | 0.5835             | 0.5477                     |
#
# **Conclusion:**
# The previous ResNet-18 shows superior performance in both accuracy and ROC-AUC for the **ACL** class compared to the new ResNet-18.
#
# ### 3. MENISCUS Class
#
# | Metric             | Previous ResNet-18 | New ResNet-18 (LR=0.0001) |
# |--------------------|--------------------|----------------------------|
# | **Train Accuracy** | 90.09%             | 64.87%                     |
# | **Train ROC-AUC**  | 0.9599             | 0.5130                     |
# | **Valid Accuracy** | 54.17%             | 56.67%                     |
# | **Valid ROC-AUC**  | 0.6202             | 0.5170                     |
#
# **Conclusion:**
# While the new ResNet-18 shows a slight improvement in validation accuracy for the **MENISCUS** class, the ROC-AUC remains significantly lower, indicating poorer discriminative ability.
#
# ## C. Overall Performance
#
# - **ResNet-18 (Previous):**
#   - **High Training Performance:** The model fits the training data exceptionally well, as evidenced by high accuracies and ROC-AUC scores.
#   - **Moderate Validation Performance:** Despite overfitting, the validation metrics are reasonably good, especially for the ABNORMAL class.
#
# - **ResNet-18 (New with LR=0.0001):**
#   - **Lower Training Performance:** The model does not fit the training data as well, resulting in lower accuracies and ROC-AUC scores.
#   - **Comparable or Slightly Lower Validation Performance:** Validation metrics are on par or slightly worse than the previous model, despite a lower validation loss.
#
# ## D. Potential Reasons for ResNet-18 (New) Underperformance
#
# - **Learning Rate Adjustment:**
#   - **Lower Learning Rate (0.0001):** The reduced learning rate may have slowed down the training process, preventing the model from adequately fitting the training data within 20 epochs.
#
# - **Model Capacity:**
#   - **ResNet-18's Flexibility:** Even though ResNet-18 is less complex than deeper models, the change in learning rate may have affected its ability to learn effectively from the data.
#
# - **Training Duration:**
#   - **Insufficient Epochs:** With a lower learning rate, the model might require more epochs to converge and achieve better performance.
#
# - **Regularization Techniques:**
#   - **Potential Over-regularization:** If additional regularization was applied (e.g., dropout, weight decay), it might have hindered the model's ability to learn from the training data.
#
# - **Batch Size and Optimization:**
#   - **Batch Size Impact:** The chosen batch size in training could influence the optimization dynamics, especially with a lower learning rate.
#   - **Optimizer Configuration:** The optimizer settings (e.g., momentum, weight decay) might need adjustment to complement the lower learning rate.
#
# ---
#
# # Recommendations
#
# **Revert to the Previous ResNet-18 Configuration:**
#
# Given the substantial drop in performance metrics with the new ResNet-18 (LR=0.0001), it is advisable to continue with the **previous ResNet-18 configuration**. The earlier model demonstrated superior training and validation performance, particularly in critical classes like **ABNORMAL** and **ACL**.
